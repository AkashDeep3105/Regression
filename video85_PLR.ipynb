# %% [markdown]
# # DATA PREPROCESSING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("C:\\Users\\ad310\\Desktop\\MACHINE LEARNING\\drive-download-20241214T151724Z-001\\Part 2 - Regression\\Section 6 - Polynomial Regression\\Python\\Position_Salaries.csv")
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# # TRAINING SLR AND VISUALISING RESULT

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=lin_reg.predict(x)

# %%
plt.scatter(x,y,color='red')
plt.plot(x,y_pred,color='blue')
plt.title('salary vs expectation(SLR)')
plt.xlabel('level')
plt.ylabel('salary')
plt.show()

# %% [markdown]
# # TRAINING PLR AND VISUALISING RESULT

# %% [markdown]
# POWERED MATRIX OF FEATURE

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=4)
x_poly=poly_reg.fit_transform(x)

# %%
lin_reg2=LinearRegression()
lin_reg2.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
y_poly_pred=lin_reg2.predict(x_poly)
plt.scatter(x,y,color='red')
plt.plot(x,y_poly_pred,color='blue')
plt.title('salary vs expectation(PLR)')
plt.xlabel('level')
plt.ylabel('salary')
plt.show()

# %% [markdown]
# # PREDICTING RESULT FOR SLR AND PLR

# %%
#SLR
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
#PLR
lin_reg2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265153])
